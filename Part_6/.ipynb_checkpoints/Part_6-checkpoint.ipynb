# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

# %%
data = 'chocolate_dataset.csv'

df = pd.read_csv(data)

# %%
df
# Out:
#              code                                 name quantity  \
# 0    1.330512e+07                 crosti pétales choc'    425.0
# 1    1.347439e+07  Biscottes d'épeautre à la châtaigne      150
# 2    1.740750e+07                               KLASIK      570
# 3    1.746122e+07                   la mini tartelette      225
# 4    1.789472e+07                    pains au chocolat      360
# ..            ...                                  ...      ...
# 634  8.717271e+07                 Dark chocolate chips      350
# 635  8.760120e+11                 Dark chocolate chips      200
# 636  9.176465e+12                Croustillant chocolat      500
# 637  9.542032e+09             Dark Chocolate 78% cocoa   3.5 oz
# 638  9.731820e+05                 Crosti pétales choc'      425
#
#                 brands      Energy  Saturated_fatty_acids     Sugars  Fiber  \
# 0          j.Favrichon  115.000000                   0.60   7.800000   2.40
# 1    moulin des moines  354.000000                   0.15   4.450000   3.03
# 2                    U  582.000000                   6.40  44.000000   3.80
# 3               p'déli  500.000000                  12.00  34.000000   2.00
# 4                    U  183.000000                   5.90   5.900000   1.20
# ..                 ...         ...                    ...        ...    ...
# 634            Penotti  568.000000                   9.00  49.000000   5.00
# 635             Deavas  524.000000                  21.43  38.100000   7.10
# 636              Bjorg  461.000000                   4.30  15.000000   8.20
# 637              Lindt  566.666667                  30.00  16.666667   7.50
# 638             Crosti  233.000000                   1.40  11.000000   5.40
#
#      Proteins    Salt  Fruit/vegetable Nutriscore  Nutriscore_point
# 0        3.00    0.11              0.0          a              -1.0
# 1       14.41    1.11              0.0          b               0.0
# 2        6.70    0.09             13.0          d              18.0
# 3        7.00    1.50              0.0          e              27.0
# 4        3.00    0.41              0.0          e              19.0
# ..        ...     ...              ...        ...               ...
# 634      3.20    0.00              0.0          e              20.0
# 635      7.14  150.00              0.0          e              19.0
# 636     10.00    0.03              0.0          c               7.0
# 637     10.00    0.00              0.0          d              15.0
# 638      6.30    0.20              0.0          a              -3.0
#
# [639 rows x 13 columns]

# %% [markdown]
# ### exploratory data analysis

# %%
df.describe()
# Out:
#                code       Energy  Saturated_fatty_acids      Sugars  \
# count  6.390000e+02   639.000000             639.000000  639.000000
# mean   3.711451e+12   417.275067               8.934853   24.206765
# std    1.714374e+12   143.417500               7.796612   10.628539
# min    3.196380e+05     0.000000               0.000000    0.000000
# 25%    3.258123e+12   377.000000               2.600000   17.000000
# 50%    3.523230e+12   433.000000               6.000000   23.000000
# 75%    3.770005e+12   494.500000              14.000000   29.000000
# max    9.176465e+12  2059.000000              42.000000   62.000000
#
#             Fiber    Proteins         Salt  Fruit/vegetable  Nutriscore_point
# count  639.000000  639.000000   639.000000       639.000000        639.000000
# mean     5.602905    8.151487     9.837697         2.763052         11.452269
# std      3.760226    5.047454    88.418741        11.687745          7.053123
# min      0.000000    0.000000     0.000000         0.000000         -6.000000
# 25%      2.800000    6.150000     0.030000         0.000000          7.000000
# 50%      5.300000    7.500000     0.110000         0.000000         11.000000
# 75%      8.000000    9.300000     0.300000         0.000000         17.000000
# max     38.000000   88.000000  1155.000000       118.000000         31.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 639 entries, 0 to 638
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   code                   639 non-null    float64
#  1   name                   622 non-null    object
#  2   quantity               639 non-null    object
#  3   brands                 639 non-null    object
#  4   Energy                 639 non-null    float64
#  5   Saturated_fatty_acids  639 non-null    float64
#  6   Sugars                 639 non-null    float64
#  7   Fiber                  639 non-null    float64
#  8   Proteins               639 non-null    float64
#  9   Salt                   639 non-null    float64
#  10  Fruit/vegetable        639 non-null    float64
#  11  Nutriscore             639 non-null    object
#  12  Nutriscore_point       639 non-null    float64
# dtypes: float64(9), object(4)
# memory usage: 65.0+ KB

# %%
df.shape
# Out:
# (639, 13)

# %%
for col in df.columns:
    
    print(df[col].value_counts())
# Out:
# 1.330512e+07    1
# 3.760266e+12    1
# 3.760182e+12    1
# 3.760182e+12    1
# 3.760212e+12    1
#                ..
# 3.396410e+12    1
# 3.396410e+12    1
# 3.396411e+12    1
# 3.396411e+12    1
# 9.731820e+05    1
# Name: code, Length: 639, dtype: int64
# Dark chocolate chips                        8
# Chocola                                     7
# Mousse au chocolat noir                     5
# Galettes de riz chocolat noir               5
# Granola chocolat noir                       4
#                                            ..
# Chocolat noir Inde 70% de cacao             1
# Muesli Sarrasin Chocolat                    1
# Galettes de riz complet chocolat noir       1
# Galette de riz au Chocolat noir et  coco    1
# Crosti pétales choc'                        1
# Name: name, Length: 545, dtype: int64
# 200            102
# 100             52
# 375             45
# 100.0           34
# 500             24
#               ...
# 487,5            1
# 45 cl / 220      1
# &-à              1
# 95               1
# 3.5 oz           1
# Name: quantity, Length: 145, dtype: int64
# U                             15
# La Vie Claire                 13
# Alnatura                      13
# Bjorg                         13
# Biocoop                       11
#                               ..
# Bio Village, Marque Repère     1
# bio village                    1
# Reauté Chocolat                1
# Biscuiterie De Provence        1
# Crosti                         1
# Name: brands, Length: 353, dtype: int64
# 390.000000    8
# 391.000000    7
# 504.000000    7
# 380.000000    7
# 497.000000    7
#              ..
# 505.000000    1
# 359.000000    1
# 332.000000    1
# 151.000000    1
# 566.666667    1
# Name: Energy, Length: 299, dtype: int64
# 14.00    32
# 15.00    21
# 13.00    16
# 1.10     16
# 16.00    15
#          ..
# 10.00     1
# 11.80     1
# 5.93      1
# 0.76      1
# 17.10     1
# Name: Saturated_fatty_acids, Length: 200, dtype: int64
# 20.000000    29
# 27.000000    28
# 24.000000    28
# 18.000000    25
# 21.000000    21
#              ..
# 22.860000     1
# 54.800000     1
# 22.100000     1
# 53.000000     1
# 16.666667     1
# Name: Sugars, Length: 206, dtype: int64
# 0.00     49
# 5.00     23
# 11.00    17
# 3.50     15
# 8.00     15
#          ..
# 11.90     1
# 38.00     1
# 4.81      1
# 4.23      1
# 12.30     1
# Name: Fiber, Length: 140, dtype: int64
# 9.0     34
# 10.0    20
# 7.0     20
# 11.0    19
# 8.0     17
#         ..
# 12.1     1
# 11.8     1
# 8.1      1
# 1.9      1
# 3.2      1
# Name: Proteins, Length: 160, dtype: int64
# 0.1000     56
# 0.0000     53
# 0.0200     45
# 0.0100     36
# 0.2000     24
#            ..
# 0.0048      1
# 0.2170      1
# 1.4000      1
# 69.0000     1
# 0.5250      1
# Name: Salt, Length: 122, dtype: int64
# 0.000      568
# 13.000       3
# 2.000        3
# 9.000        3
# 6.000        3
# 3.000        3
# 27.000       2
# 11.111       2
# 10.000       2
# 20.000       2
# 24.000       2
# 48.000       2
# 14.000       2
# 38.000       2
# 80.000       2
# 9.480        1
# 56.800       1
# 53.100       1
# 23.490       1
# 35.000       1
# 100.000      1
# 40.250       1
# 5.000        1
# 14.290       1
# 64.000       1
# 8.667        1
# 84.000       1
# 12.000       1
# 0.750        1
# 15.200       1
# 75.000       1
# 15.000       1
# 8.000        1
# 12.500       1
# 0.500        1
# 78.000       1
# 40.500       1
# 9.700        1
# 35.700       1
# 16.000       1
# 10.300       1
# 8.100        1
# 30.000       1
# 19.874       1
# 7.000        1
# 13.200       1
# 4.100        1
# 16.667       1
# 4.000        1
# 60.000       1
# 16.700       1
# 118.000      1
# 1.500        1
# Name: Fruit/vegetable, dtype: int64
# d    226
# c    225
# e    103
# b     58
# a     27
# Name: Nutriscore, dtype: int64
#  7.0     52
#  9.0     45
#  18.0    44
#  8.0     42
#  16.0    39
#  0.0     32
#  17.0    32
#  6.0     29
#  10.0    28
#  19.0    27
#  15.0    25
#  14.0    24
#  11.0    23
#  12.0    20
#  13.0    19
#  20.0    15
#  21.0    15
#  2.0     15
#  4.0     14
# -1.0     13
#  22.0    12
#  1.0     11
#  5.0      9
#  24.0     8
# -2.0      8
#  25.0     8
#  23.0     7
#  26.0     7
#  3.0      6
# -3.0      3
#  27.0     2
# -4.0      2
#  28.0     1
#  31.0     1
# -6.0      1
# Name: Nutriscore_point, dtype: int64

# %%
df.value_counts()
# Out:
# code          name                                    quantity  brands                                  Energy  Saturated_fatty_acids  Sugars  Fiber  Proteins  Salt  Fruit/vegetable  Nutriscore  Nutriscore_point
# 3.196380e+05  Dark chocolate chips                    200       M&S                                     445.0   6.7                    57.7    2.3    3.3       1.55  0.0              e            25.0               1
# 3.760050e+12  Mon goûter briochette choco lait        200       LA BOULANGÈRE BIO                       363.0   3.8                    12.0    3.1    8.5       0.90  0.0              c            9.0                1
# 3.760000e+12  Crème chocolat au lait entier 400g CC   400.0     Biocoop                                 128.0   3.1                    14.0    0.8    3.6       0.10  0.0              c            5.0                1
# 3.760014e+12  Muesli au Chocolat                      100       Voyager,Falières Nutrition              412.0   4.0                    23.5    9.6    12.1      0.10  0.0              c            8.0                1
# 3.760021e+12  Muesli chocolat noir et graines de lin  375.0     Jardin Bio étic,Léa Nature, Jardin bio  397.0   3.3                    11.0    11.0   11.0      0.03  0.0              a           -1.0                1
#                                                                                                                                                                                                                       ..
# 3.288133e+12  Cool Pétales Chocolat                   450.0     Vitabio                                 387.0   1.6                    21.0    7.6    9.7       0.18  0.0              a           -1.0                1
# 3.297760e+12  Dessert gourmand chocolat               220       Charles & Alice                         159.0   6.5                    17.0    1.2    1.5       0.02  0.0              c            8.0                1
#               Dessert Gourmand Végétal au Chocolat    2 x 110   Happy Coco!                             177.0   8.5                    17.0    1.2    1.6       0.01  0.0              d            11.0               1
# 3.322680e+12  Whaou Bio                               6x32      Whaou!                                  464.0   3.7                    36.0    2.6    7.1       0.85  0.0              d            16.0               1
# 9.176465e+12  Croustillant chocolat                   500       Bjorg                                   461.0   4.3                    15.0    8.2    10.0      0.03  0.0              c            7.0                1
# Length: 622, dtype: int64

# %%
df["Nutriscore"].value_counts() # distribution of target variable
# Out:
# d    226
# c    225
# e    103
# b     58
# a     27
# Name: Nutriscore, dtype: int64

# %%
df.isnull().sum()  # looking for empty values
# Out:
# code                      0
# name                     17
# quantity                  0
# brands                    0
# Energy                    0
# Saturated_fatty_acids     0
# Sugars                    0
# Fiber                     0
# Proteins                  0
# Salt                      0
# Fruit/vegetable           0
# Nutriscore                0
# Nutriscore_point          0
# dtype: int64

# %%
# X = df.drop(['code','quantity','Nutriscore','Nutriscore_point','name','brands'], axis=1)
X = df.drop(['quantity','Nutriscore','Nutriscore_point','name','brands'], axis=1)

y = df['Nutriscore']

# %%
print(X.shape,y.shape)
# Out:
# (639, 8) (639,)

# %% [markdown]
# ### feature engineering

# %%
X.dtypes   # name of product and brand are of type object, we need to convert them into numbers, so ml model can inderstand
# Out:
# code                     float64
# Energy                   float64
# Saturated_fatty_acids    float64
# Sugars                   float64
# Fiber                    float64
# Proteins                 float64
# Salt                     float64
# Fruit/vegetable          float64
# dtype: object

# %%
y.dtypes # target variable is object type
# Out:
# dtype('O')

# %%
y.value_counts()
# Out:
# d    226
# c    225
# e    103
# b     58
# a     27
# Name: Nutriscore, dtype: int64

# %%
import category_encoders as ce
# encode variables with ordinal encoding

#encoder = ce.OrdinalEncoder(cols=['product_name_fr','brands','off:nutriscore_grade'])
encoder = ce.OrdinalEncoder(cols=['Nutriscore'])
y = encoder.fit_transform(y)
# X_train = encoder.fit_transform(X_train)

# X_test = encoder.transform(X_test)

# %%
y.value_counts()
# Out:
# Nutriscore
# 3             226
# 5             225
# 4             103
# 2              58
# 1              27
# dtype: int64

# %%
y
# Out:
#      Nutriscore
# 0             1
# 1             2
# 2             3
# 3             4
# 4             4
# ..          ...
# 634           4
# 635           4
# 636           5
# 637           3
# 638           1
#
# [639 rows x 1 columns]

# %%
encoder.inverse_transform(y)
# Out:
#     Nutriscore
# 0            a
# 1            b
# 2            d
# 3            e
# 4            e
# ..         ...
# 634          e
# 635          e
# 636          c
# 637          d
# 638          a
#
# [639 rows x 1 columns]

# %% [markdown]
# ### split into train, test data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42, stratify = y)

# %%
X_test.shape
# Out:
# (211, 8)

# %%
y_train.value_counts()
# Out:
# Nutriscore
# 3             151
# 5             151
# 4              69
# 2              39
# 1              18
# dtype: int64

# %%
y_test.value_counts()
# Out:
# Nutriscore
# 3             75
# 5             74
# 4             34
# 2             19
# 1              9
# dtype: int64

# %% [markdown]
# ### Decision Tree

# %%
# import DecisionTreeClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.tree import DecisionTreeClassifier

best_acc = 0

for criterion in "gini", "entropy":
    for max_depth in [2,3,4,5,6]:
        for min_samples_leaf in [5, 10, 20, 30]:
            dtree = DecisionTreeClassifier(max_depth=max_depth, criterion=criterion, min_samples_leaf=min_samples_leaf,random_state=42)
            dtree.fit(X_train, y_train)
            predicitions = dtree.predict(X_test)
            acc = accuracy_score(y_test, predicitions)
            if acc > best_acc:
                best_params = f"criterion: {criterion}, max_depth: {max_depth}, min_samples_leaf: {min_samples_leaf}"
                best_acc = acc

# %%
best_acc
# Out:
# 0.8151658767772512

# %%
best_params
# Out:
# 'criterion: gini, max_depth: 6, min_samples_leaf: 5'

# %%
clf_gini = DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=42,min_samples_leaf=5)


# fit the model
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, min_samples_leaf=5,
#                        random_state=42)

# %%
y_pred_gini = clf_gini.predict(X_test)
y_pred_gini
# Out:
# array([5, 3, 4, 3, 4, 3, 2, 5, 3, 2, 5, 5, 5, 2, 3, 4, 3, 4, 5, 2, 2, 3,
#        3, 3, 3, 3, 5, 2, 5, 5, 4, 3, 3, 5, 5, 5, 3, 5, 3, 4, 5, 3, 5, 5,
#        4, 5, 3, 5, 5, 2, 3, 2, 2, 2, 1, 5, 4, 5, 3, 3, 3, 2, 5, 5, 2, 4,
#        2, 2, 5, 5, 5, 3, 3, 3, 3, 3, 3, 5, 5, 2, 5, 3, 5, 5, 5, 5, 2, 2,
#        3, 5, 5, 3, 3, 2, 5, 2, 4, 5, 3, 5, 3, 3, 3, 3, 5, 1, 3, 5, 4, 3,
#        5, 2, 3, 3, 5, 2, 1, 5, 5, 3, 5, 2, 4, 5, 4, 5, 2, 4, 4, 3, 5, 3,
#        3, 5, 3, 4, 5, 3, 2, 2, 5, 3, 3, 4, 5, 4, 4, 3, 3, 4, 4, 5, 3, 4,
#        4, 5, 5, 3, 5, 4, 5, 2, 5, 4, 3, 3, 2, 2, 3, 2, 4, 5, 2, 2, 3, 2,
#        3, 5, 3, 5, 4, 3, 5, 4, 5, 3, 3, 5, 2, 5, 4, 5, 2, 5, 5, 4, 3, 5,
#        2, 3, 4, 3, 5, 4, 1, 5, 3, 3, 5, 5, 2])

# %%
print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.7820

# %%
y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array([5, 2, 5, 2, 2, 3, 5, 4, 4, 3, 3, 4, 5, 5, 5, 3, 3, 3, 3, 5, 3, 3,
#        2, 3, 5, 5, 3, 3, 3, 3, 3, 3, 3, 5, 4, 3, 5, 2, 3, 3, 3, 2, 3, 5,
#        5, 5, 3, 4, 5, 3, 5, 5, 3, 3, 5, 3, 5, 3, 5, 3, 3, 3, 2, 3, 3, 4,
#        5, 3, 3, 5, 3, 5, 5, 3, 5, 4, 5, 5, 5, 2, 3, 3, 2, 4, 5, 4, 2, 3,
#        5, 3, 5, 1, 3, 3, 3, 5, 5, 2, 3, 5, 5, 3, 3, 2, 2, 3, 5, 3, 4, 4,
#        4, 4, 3, 5, 3, 2, 2, 3, 5, 3, 3, 4, 3, 4, 5, 3, 3, 5, 3, 3, 2, 3,
#        2, 2, 3, 3, 3, 5, 5, 4, 2, 2, 3, 5, 2, 3, 4, 5, 5, 4, 5, 5, 5, 5,
#        3, 2, 5, 5, 3, 3, 5, 5, 3, 2, 5, 5, 4, 4, 2, 3, 3, 5, 5, 3, 5, 3,
#        4, 1, 5, 2, 5, 4, 3, 1, 5, 5, 5, 2, 2, 2, 1, 5, 4, 5, 1, 2, 3, 4,
#        3, 3, 5, 3, 3, 5, 5, 5, 5, 3, 5, 5, 3, 5, 2, 4, 4, 2, 5, 5, 4, 2,
#        5, 3, 3, 2, 4, 5, 5, 2, 3, 4, 2, 4, 5, 5, 4, 5, 5, 5, 5, 3, 5, 3,
#        2, 2, 4, 3, 3, 4, 5, 2, 5, 5, 5, 3, 5, 5, 3, 3, 5, 3, 5, 5, 5, 3,
#        3, 5, 3, 5, 2, 4, 3, 5, 5, 4, 5, 3, 4, 3, 3, 5, 3, 5, 5, 4, 2, 3,
#        4, 5, 5, 4, 5, 5, 3, 3, 3, 5, 5, 4, 3, 5, 4, 4, 5, 4, 5, 3, 3, 4,
#        3, 5, 3, 3, 2, 5, 4, 3, 5, 2, 5, 3, 3, 5, 3, 3, 3, 2, 2, 5, 3, 5,
#        2, 5, 3, 3, 3, 5, 5, 5, 4, 3, 5, 5, 4, 3, 4, 5, 5, 3, 5, 3, 1, 4,
#        4, 5, 5, 2, 5, 3, 4, 3, 4, 2, 2, 4, 5, 4, 5, 3, 3, 4, 2, 5, 4, 2,
#        3, 2, 5, 3, 5, 5, 5, 3, 2, 5, 3, 5, 3, 4, 5, 1, 3, 4, 5, 1, 2, 2,
#        5, 2, 5, 3, 2, 5, 2, 3, 4, 3, 4, 4, 3, 4, 5, 3, 3, 2, 3, 5, 3, 3,
#        2, 3, 3, 3, 5, 5, 5, 5, 2, 3])

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_gini)))
# Out:
# Training-set accuracy score: 0.8738

# %%
# print the scores on training and test set, check overfitting 

print('Training set score: {:.4f}'.format(clf_gini.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_gini.score(X_test, y_test)))
# Out:
# Training set score: 0.8738
# Test set score: 0.7820

# %%
X_train.shape
# Out:
# (428, 8)

# %%
X_test.shape
# Out:
# (211, 8)

# %%
# plt.figure(figsize=(12,8))

# from sklearn import tree

# tree.plot_tree(clf_gini.fit(X_train, y_train))

# %% [markdown]
# d    226
# c    225
# e    103
# b     58
# a     27
# Nutriscore
# 3             75
# 5             74
# 4             34
# 2             19
# 1              9
# dtype: int64

# %%
import graphviz 
dot_data = tree.export_graphviz(clf_gini, out_file=None, 
                              feature_names=X.columns,  
                              class_names=['a','b','d','e','c'],  
                              filled=True, rounded=True,  
                              special_characters=True)

graph = graphviz.Source(dot_data) 

graph

# %%
graph.render()  #to save above picture
# Out:
# 'Source.gv.pdf'

# %%
# from sklearn.tree import plot_tree
# import matplotlib.pyplot as plt

# fig = plt.figure(figsize=((25,20)))
# plot_tree(clf_gini,
#             feature_names = X.columns,
#             class_names=['a','b','d','e','c'], 
#             impurity=False,
#             proportion=True,
#             filled=True)
# fig.savefig('test.png')

# %%
from matplotlib import pyplot
importance = clf_gini.feature_importances_
for i,v in zip(X_train.columns,importance):
    print(i,v)
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# code 0.0
# Energy 0.05418151999414799
# Saturated_fatty_acids 0.4876749175394603
# Sugars 0.30124901922773806
# Fiber 0.09324400473348564
# Proteins 0.009916891042453694
# Salt 0.053733647462714244
# Fruit/vegetable 0.0

# %%
for i,y in zip(X_train.columns,importance):
    print (i,y)   # feature importance with its name
# Out:
# code 0.0
# Energy 0.05418151999414799
# Saturated_fatty_acids 0.4876749175394603
# Sugars 0.30124901922773806
# Fiber 0.09324400473348564
# Proteins 0.009916891042453694
# Salt 0.053733647462714244
# Fruit/vegetable 0.0

# %% [markdown]
# ### Confusion matrix

# %%
# Print the Confusion Matrix and slice it into four pieces

import seaborn as sns
import matplotlib.pyplot as plt    

cm = confusion_matrix(y_test, y_pred_gini)

print('Confusion matrix\n\n', cm)

ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['a','b','d','e','c']); ax.yaxis.set_ticklabels(['a','b','d','e','c']);
from sklearn.metrics import confusion_matrix
# Out:
# Confusion matrix
#
#  [[ 3  5  0  0  1]
#  [ 1 15  0  0  3]
#  [ 0  1 60  3 11]
#  [ 0  0  5 29  0]
#  [ 0 15  1  0 58]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_gini))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.33      0.46         9
#            2       0.42      0.79      0.55        19
#            3       0.91      0.80      0.85        75
#            4       0.91      0.85      0.88        34
#            5       0.79      0.78      0.79        74
#
#     accuracy                           0.78       211
#    macro avg       0.76      0.71      0.71       211
# weighted avg       0.82      0.78      0.79       211

# %%
# to get all the predicted nutriscore

y_pred = clf_gini.predict(X)

# %%
#to save the results 
X['Original_Nutriscore'] = encoder.inverse_transform(y)

# %%
X
# Out:
#              code      Energy  Saturated_fatty_acids     Sugars  Fiber  \
# 0    1.330512e+07  115.000000                   0.60   7.800000   2.40
# 1    1.347439e+07  354.000000                   0.15   4.450000   3.03
# 2    1.740750e+07  582.000000                   6.40  44.000000   3.80
# 3    1.746122e+07  500.000000                  12.00  34.000000   2.00
# 4    1.789472e+07  183.000000                   5.90   5.900000   1.20
# ..            ...         ...                    ...        ...    ...
# 634  8.717271e+07  568.000000                   9.00  49.000000   5.00
# 635  8.760120e+11  524.000000                  21.43  38.100000   7.10
# 636  9.176465e+12  461.000000                   4.30  15.000000   8.20
# 637  9.542032e+09  566.666667                  30.00  16.666667   7.50
# 638  9.731820e+05  233.000000                   1.40  11.000000   5.40
#
#      Proteins    Salt  Fruit/vegetable Original_Nutriscore
# 0        3.00    0.11              0.0                   a
# 1       14.41    1.11              0.0                   b
# 2        6.70    0.09             13.0                   d
# 3        7.00    1.50              0.0                   e
# 4        3.00    0.41              0.0                   e
# ..        ...     ...              ...                 ...
# 634      3.20    0.00              0.0                   e
# 635      7.14  150.00              0.0                   e
# 636     10.00    0.03              0.0                   c
# 637     10.00    0.00              0.0                   d
# 638      6.30    0.20              0.0                   a
#
# [639 rows x 9 columns]

# %%
y_pred = pd.DataFrame(y_pred , columns = ['Nutriscore'])

# %%
X['Predicted_Nutriscore_ML'] = encoder.inverse_transform(y_pred)

# %%
X
# Out:
#              code      Energy  Saturated_fatty_acids     Sugars  Fiber  \
# 0    1.330512e+07  115.000000                   0.60   7.800000   2.40
# 1    1.347439e+07  354.000000                   0.15   4.450000   3.03
# 2    1.740750e+07  582.000000                   6.40  44.000000   3.80
# 3    1.746122e+07  500.000000                  12.00  34.000000   2.00
# 4    1.789472e+07  183.000000                   5.90   5.900000   1.20
# ..            ...         ...                    ...        ...    ...
# 634  8.717271e+07  568.000000                   9.00  49.000000   5.00
# 635  8.760120e+11  524.000000                  21.43  38.100000   7.10
# 636  9.176465e+12  461.000000                   4.30  15.000000   8.20
# 637  9.542032e+09  566.666667                  30.00  16.666667   7.50
# 638  9.731820e+05  233.000000                   1.40  11.000000   5.40
#
#      Proteins    Salt  Fruit/vegetable Original_Nutriscore  \
# 0        3.00    0.11              0.0                   a
# 1       14.41    1.11              0.0                   b
# 2        6.70    0.09             13.0                   d
# 3        7.00    1.50              0.0                   e
# 4        3.00    0.41              0.0                   e
# ..        ...     ...              ...                 ...
# 634      3.20    0.00              0.0                   e
# 635      7.14  150.00              0.0                   e
# 636     10.00    0.03              0.0                   c
# 637     10.00    0.00              0.0                   d
# 638      6.30    0.20              0.0                   a
#
#     Predicted_Nutriscore_ML
# 0                         a
# 1                         b
# 2                         d
# 3                         e
# 4                         b
# ..                      ...
# 634                       d
# 635                       e
# 636                       c
# 637                       d
# 638                       b
#
# [639 rows x 10 columns]

# %%
cm = confusion_matrix(X['Original_Nutriscore'], X['Predicted_Nutriscore_ML'])
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted Nutriscore');ax.set_ylabel('Original Nutriscore'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['a','b','d','e','c']); ax.yaxis.set_ticklabels(['a','b','d','e','c']);
from sklearn.metrics import confusion_matrix

# %%
X.to_csv("results.csv")

# %% [markdown]
# # extra

# %% [markdown]
# ### criteria entropy

# %%
# instantiate the DecisionTreeClassifier model with criterion entropy

clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)


# fit the model
clf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
y_pred_en = clf_en.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Model accuracy score with criterion entropy: 0.7215

# %%
y_pred_train_en = clf_en.predict(X_train)

y_pred_train_en
# Out:
# array([1, 1, 2, 2, 4, 2, 3, 4, 2, 3, 2, 3, 1, 4, 2, 2, 2, 1, 4, 4, 4, 4,
#        1, 4, 4, 4, 1, 3, 2, 1, 2, 1, 2, 4, 2, 2, 3, 2, 2, 4, 4, 3, 4, 2,
#        1, 1, 2, 4, 2, 1, 4, 3, 4, 4, 4, 3, 3, 1, 2, 2, 1, 2, 4, 2, 3, 2,
#        2, 3, 1, 1, 3, 4, 4, 4, 1, 4, 1, 2, 1, 3, 3, 2, 4, 2, 1, 2, 2, 2,
#        5, 3, 1, 2, 4, 2, 1, 4, 1, 2, 3, 1, 4, 3, 2, 2, 2, 2, 4, 2, 4, 3,
#        1, 4, 1, 3, 2, 4, 4, 2, 4, 2, 2, 2, 4, 2, 3, 1, 2, 4, 2, 4, 4, 1,
#        2, 2, 4, 1, 3, 2, 3, 5, 2, 1, 2, 1, 4, 3, 2, 2, 4, 2, 3, 4, 4, 2,
#        4, 4, 2, 1, 2, 4])

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set accuracy score: 0.8375

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf_en.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_en.score(X_test, y_test)))
# Out:
# Training set score: 0.8375
# Test set score: 0.7215

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_en.fit(X_train, y_train))
# Out:
# [Text(0.5, 0.875, 'X[1] <= 9.2\nentropy = 2.18\nsamples = 160\nvalue = [33, 57, 27, 30, 13]'),
#  Text(0.25, 0.625, 'X[1] <= 3.25\nentropy = 1.609\nsamples = 105\nvalue = [6, 56, 0, 30, 13]'),
#  Text(0.125, 0.375, 'X[5] <= 0.455\nentropy = 1.547\nsamples = 56\nvalue = [1, 14, 0, 30, 11]'),
#  Text(0.0625, 0.125, 'entropy = 1.244\nsamples = 46\nvalue = [0, 5, 0, 30, 11]'),
#  Text(0.1875, 0.125, 'entropy = 0.469\nsamples = 10\nvalue = [1, 9, 0, 0, 0]'),
#  Text(0.375, 0.375, 'X[2] <= 9.1\nentropy = 0.715\nsamples = 49\nvalue = [5, 42, 0, 0, 2]'),
#  Text(0.3125, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.4375, 0.125, 'entropy = 0.489\nsamples = 47\nvalue = [5, 42, 0, 0, 0]'),
#  Text(0.75, 0.625, 'X[2] <= 31.6\nentropy = 1.113\nsamples = 55\nvalue = [27, 1, 27, 0, 0]'),
#  Text(0.625, 0.375, 'X[3] <= 4.15\nentropy = 0.708\nsamples = 28\nvalue = [24, 1, 3, 0, 0]'),
#  Text(0.5625, 0.125, 'entropy = 0.954\nsamples = 8\nvalue = [5, 0, 3, 0, 0]'),
#  Text(0.6875, 0.125, 'entropy = 0.286\nsamples = 20\nvalue = [19, 1, 0, 0, 0]'),
#  Text(0.875, 0.375, 'X[3] <= 8.95\nentropy = 0.503\nsamples = 27\nvalue = [3, 0, 24, 0, 0]'),
#  Text(0.8125, 0.125, 'entropy = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0, 0]'),
#  Text(0.9375, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]')]

# %%
c    86
d    49
b    45
e    40
a    19

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

fig = plt.figure(figsize=((25,20)))
plot_tree(dtree,
            feature_names = X.columns,
            class_names=['c','d','b','e','a'], 
            impurity=False,
            proportion=True,
            filled=True)
fig.savefig('test.png')

# %%
d    49
e    40
c    21
b
